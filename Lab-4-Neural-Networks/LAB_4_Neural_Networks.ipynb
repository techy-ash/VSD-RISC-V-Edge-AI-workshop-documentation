# %%
from tensorflow.keras.datasets import mnist
from sklearn.model_selection import train_test_split
import numpy as np

# %%
#X, y = load_digits(return_X_y=True)

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train = X_train.reshape(-1, 28*28).astype(np.float32)
X_test = X_test.reshape(-1, 28*28).astype(np.float32)
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

# %%
mlp = MLPClassifier(hidden_layer_sizes=(64,32,), activation='relu', solver='adam', max_iter=300)

# %%
mlp.fit(X_train, y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=(64, 32), max_iter=300)

# %%
y_pred = mlp.predict(X_test)

# %%
print(f"Accuracy: {accuracy_score(y_test, y_pred):.2f}")
# Out:
# Accuracy: 0.97

# %% [markdown]
# input -> hidden l1 weights: 784* 64
# biases = 64* 1
#
# hidden l1 -> hidden l2 weights: 64* 32
# biases = 32* 1
#
# hidden l2 -> output weights: 32* 10
# biases = 10 * 1

# %%
total_params = sum(w.size for w in mlp.coefs_) + sum(b.size for b in mlp.intercepts_)
print(total_params)
# Out:
# 52650

# %%
X_train.shape
# Out:
# (60000, 784)

# %%
print(mlp.coefs_)
print(mlp.intercepts_)
# Out:
# [array([[-4.9638139e-39, -3.5894372e-39,  1.0210935e-38, ...,
#         -3.4697495e-39,  3.8670961e-39,  1.1079101e-38],
#        [-1.3441815e-38,  7.9714979e-39, -6.5676603e-39, ...,
#          3.8262090e-39, -1.3553172e-38, -9.4084692e-39],
#        [ 1.3573948e-38,  9.1019828e-39, -4.8301637e-39, ...,
#          1.0987217e-39, -1.3186049e-38, -1.3539326e-38],
#        ...,
#        [-1.0459709e-38, -5.3517340e-39, -1.3699312e-38, ...,
#          1.1672529e-38,  1.0641438e-38, -1.9628632e-39],
#        [-2.7549135e-39, -6.6832086e-39,  1.1078200e-38, ...,
#         -1.8200219e-39, -1.3094480e-38,  1.1379782e-38],
#        [-2.3273858e-39, -2.2174273e-39,  2.2586087e-39, ...,
#         -9.0076446e-40,  5.2368808e-39, -7.6199177e-39]], dtype=float32), array([[ 8.4467635e-02,  4.7579661e-02, -2.1543063e-01, ...,
#         -3.8317733e-02,  2.8196905e-02,  6.1569884e-02],
#        [-1.7969823e-01, -8.6687215e-02, -4.2125165e-01, ...,
# ...
